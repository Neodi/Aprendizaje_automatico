# %% [markdown]
# **Caso Práctico: Detección de malware en Android**
#
#
# En este caso de uso práctico se pretende resolver un problema de detección de malware en dispositivos Android mediante el análisis del tráfico de red que genera el dispositivo mediante el uso de árboles de decisión.
#
#
# Descarga de los ficheros de datos
#
# https://drive.google.com/file/d/1FyRlPKiMnC2cDypeipX3lrAqy0wU3y0X/view?usp=sharing
#
#
# Referencias adicionales sobre el conjunto de datos
#
# _Arash Habibi Lashkari, Andi Fitriah A. Kadir, Hugo Gonzalez, Kenneth Fon Mbah and Ali A. Ghorbani, “Towards a Network-Based Framework for Android Malware Detection and Characterization”, In the proceeding of the 15th International Conference on Privacy, Security and Trust, PST, Calgary, Canada, 2017._
#
#
# Notas:
#
#     Puedes usar esta función auxiliar para separar las características de entrada de la salida:
#
# def remove_labels(df, label_name):
#
#   X = df.drop(label_name, axis=1)
#
#   y = df[label_name].copy()
#
#   return (X, y)
#
#
#     Y esta para probarlo con preprocesamiento o sin él:
#
# def evaluate_result(y_pred, y, y_prep_pred, y_prep, metric):
#
#   print(metric.__name__, "WITHOUT preparation:", metric(y_pred, y, average='weighted'))
#
#   print(metric.__name__, "WITH preparation:", metric(y_prep_pred, y_prep, average='weighted'))
#
#
#     Comprueba que no haya características categóricas y transforma la clase y "calss' de categórica a numérica con factorize().
#     Revisa correlaciones por si puedes eliminar alguna caractrerística de entrada muy correlacionadas entre sí, o quedarte solo con las que esté correlacionadas con la class y (calss) por encima de un umbral.
#     Otra buena acción, podría ser escalar los datos y comparar los resultados con el entrenamiento sin escalar (en árboles de decisión no es tan bueno escalarlos, incluso puede afectar al rendimiento del modelo).
#     Entrena el algoritmo con DecissionTreeClassifier de skearn.tree (con los hiperparámetros max_depth, prueba con números sobre 10 ó 20 porque números más altos pueden producir overfitting, y random_state)
#
#
# Intenta predecir adecuadamente con un f1_score > 0.89
#
#
# Extra I:
#
# Trata de visualizar el límite de decisión.que ha construido el algoritmo (representa el árbol con graphviz usando los dos atributos más correlacionados con la class de salida y escalados para poder verlos adecuadamente en la gráfica, entrénalo con poca profundidad, por ejemplo max_depth=2) .
#
#
# Extra II:
#
# Ahora entéralo con Random Forest para comprobar si mejora:
#
# from sklearn.ensemble import RandomForestClassifier con, por ejemplo, n_estimators=100
#
# Intenta predecir adecuadamente con un f1_score > 0.93

# %%
def remove_labels(df, label_name):

  X = df.drop(label_name, axis=1)

  y = df[label_name].copy()

  return (X, y)

# %%
def evaluate_result(y_pred, y, y_prep_pred, y_prep, metric):

  print(metric.__name__, "WITHOUT preparation:", metric(y_pred, y, average='weighted'))

  print(metric.__name__, "WITH preparation:", metric(y_prep_pred, y_prep, average='weighted'))

# %% [markdown]
# # Mejoroar

# %% [markdown]
# ## 14_Técnicas de selección de características

# %%
import pandas as pd
import numpy as np
import graphviz

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import RobustScaler
from sklearn.metrics import f1_score

# %%
# Construcción de una función que realice el particionado completo
def train_val_test_split(df, rstate=42, shuffle=True, stratify=None):
    strat = df[stratify] if stratify else None
    train_set, test_set = train_test_split(
        df, test_size=0.4, random_state=rstate, shuffle=shuffle, stratify=strat)
    strat = test_set[stratify] if stratify else None
    val_set, test_set = train_test_split(
        test_set, test_size=0.5, random_state=rstate, shuffle=shuffle, stratify=strat)
    return (train_set, val_set, test_set)

# %%
def remove_labels(df, label_name):
    X = df.drop(label_name, axis=1)
    y = df[label_name].copy()
    return (X, y)

# %%
df = pd.read_csv('../../datasets/TotalFeatures-ISCXFlowMeter/TotalFeatures-ISCXFlowMeter.csv')

# %%
train_set, val_set, test_set = train_val_test_split(df)

# %%
X_train, y_train = remove_labels(train_set, 'calss')
X_val, y_val = remove_labels(val_set, 'calss')
X_test, y_test = remove_labels(test_set, 'calss')

# %% [markdown]
# ### Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier

clf_rnd = RandomForestClassifier(n_estimators=50, random_state=42, n_jobs=-1)
clf_rnd.fit(X_train, y_train)
# Out:
# RandomForestClassifier(n_estimators=50, n_jobs=-1, random_state=42)

# %%
y_pred = clf_rnd.predict(X_val)

# %%
print("F1 score:", f1_score(y_pred, y_val, average='weighted'))
# Out:
# F1 score: 0.9324043007314987

# %%
clf_rnd.feature_importances_
# Out:
# array([0.03096656, 0.00303719, 0.00440737, 0.02318232, 0.01184895,
#        0.01721388, 0.00881173, 0.02199267, 0.01122589, 0.01910279,
#        0.01229994, 0.00912599, 0.0049411 , 0.01864105, 0.00468261,
#        0.01359503, 0.0060695 , 0.01755146, 0.00504174, 0.01740915,
#        0.00478204, 0.00668029, 0.00337915, 0.00937514, 0.00572423,
#        0.        , 0.        , 0.00268121, 0.00471322, 0.02948284,
#        0.0175912 , 0.02737585, 0.0276842 , 0.02610625, 0.0159516 ,
#        0.0247063 , 0.01454405, 0.02000791, 0.03888253, 0.03004006,
#        0.00794144, 0.03300505, 0.00432689, 0.0041829 , 0.01156361,
#        0.00794625, 0.        , 0.        , 0.        , 0.01207349,
#        0.02251504, 0.01938611, 0.00347552, 0.00116829, 0.00072676,
#        0.00094549, 0.00527031, 0.0106541 , 0.00290367, 0.00144508,
#        0.00254706, 0.00234171, 0.00912673, 0.00249816, 0.00228634,
#        0.00765582, 0.00907677, 0.01158292, 0.00196904, 0.0121832 ,
#        0.00783499, 0.00994449, 0.00162465, 0.00188881, 0.14141056,
#        0.03134543, 0.00328476, 0.00331256, 0.01770103])

# %%
feature_importances = {name: score for name, score in zip(list(df), clf_rnd.feature_importances_)}

# %%
feature_importances_sorted = pd.Series(feature_importances).sort_values(ascending=False)
feature_importances_sorted.head(20)
# Out:
# Init_Win_bytes_forward     0.141411
# max_flowiat                0.038883
# flow_fin                   0.033005
# Init_Win_bytes_backward    0.031345
# duration                   0.030967
# mean_flowiat               0.030040
# fPktsPerSecond             0.029483
# flowBytesPerSecond         0.027684
# flowPktsPerSecond          0.027376
# min_flowpktl               0.026106
# mean_flowpktl              0.024706
# total_fpktl                0.023182
# avgPacketSize              0.022515
# max_fpktl                  0.021993
# min_flowiat                0.020008
# fAvgSegmentSize            0.019386
# mean_fpktl                 0.019103
# total_fiat                 0.018641
# min_seg_size_forward       0.017701
# bPktsPerSecond             0.017591
# dtype: float64

# %% [markdown]
# ### Reducir con los parámetros más importantes

# %%
# Extraemos las 10 caracteristicas con mas relevancia para el algoritmo
columns = list(feature_importances_sorted.head(20).index)

# %%
columns
# Out:
# ['Init_Win_bytes_forward',
#  'max_flowiat',
#  'flow_fin',
#  'Init_Win_bytes_backward',
#  'duration',
#  'mean_flowiat',
#  'fPktsPerSecond',
#  'flowBytesPerSecond',
#  'flowPktsPerSecond',
#  'min_flowpktl',
#  'mean_flowpktl',
#  'total_fpktl',
#  'avgPacketSize',
#  'max_fpktl',
#  'min_flowiat',
#  'fAvgSegmentSize',
#  'mean_fpktl',
#  'total_fiat',
#  'min_seg_size_forward',
#  'bPktsPerSecond']

# %%
X_train_reduced = X_train[columns].copy()
X_val_reduced = X_val[columns].copy()

# %%
from sklearn.ensemble import RandomForestClassifier

clf_rnd = RandomForestClassifier(n_estimators=50, random_state=42, n_jobs=-1)
clf_rnd.fit(X_train_reduced, y_train)
# Out:
# RandomForestClassifier(n_estimators=50, n_jobs=-1, random_state=42)

# %%
y_pred = clf_rnd.predict(X_val_reduced)

# %%
print("F1 score:", f1_score(y_pred, y_val, average='weighted'))
# Out:
# F1 score: 0.934169742585424

# %% [markdown]
# ### Añadir los grid Random (con set reducido)

# %%
from sklearn.model_selection import RandomizedSearchCV
from scipy.stats import randint

param_distribs = {
        'n_estimators': randint(low=10, high=300),
        'max_depth': randint(low=10, high=55,)
        }

rnd_clf = RandomForestClassifier(n_jobs=-1)

# train across 2 folds, that's a total of 5*2=10 rounds of training
rnd_search = RandomizedSearchCV(rnd_clf, param_distributions=param_distribs,
                                n_iter=100, cv=10, scoring='f1_weighted', verbose=4)

rnd_search.fit(X_train_reduced, y_train)
# Out:
# Fitting 10 folds for each of 100 candidates, totalling 1000 fits
# [CV 1/10] END ...max_depth=36, n_estimators=137;, score=0.933 total time=  14.9s
# [CV 2/10] END ...max_depth=36, n_estimators=137;, score=0.933 total time=  16.1s
# [CV 3/10] END ...max_depth=36, n_estimators=137;, score=0.935 total time=  15.8s
# [CV 4/10] END ...max_depth=36, n_estimators=137;, score=0.932 total time=  15.4s
# [CV 5/10] END ...max_depth=36, n_estimators=137;, score=0.933 total time=  16.0s
# [CV 6/10] END ...max_depth=36, n_estimators=137;, score=0.930 total time=  15.5s
# [CV 7/10] END ...max_depth=36, n_estimators=137;, score=0.935 total time=  15.8s
# [CV 8/10] END ...max_depth=36, n_estimators=137;, score=0.933 total time=  15.9s
# [CV 9/10] END ...max_depth=36, n_estimators=137;, score=0.935 total time=  15.6s
# [CV 10/10] END ..max_depth=36, n_estimators=137;, score=0.934 total time=  15.8s
# [CV 1/10] END ....max_depth=42, n_estimators=88;, score=0.933 total time=  10.7s
# [CV 2/10] END ....max_depth=42, n_estimators=88;, score=0.933 total time=  10.2s
# [CV 3/10] END ....max_depth=42, n_estimators=88;, score=0.935 total time=  10.5s
# [CV 4/10] END ....max_depth=42, n_estimators=88;, score=0.932 total time=  10.9s
# [CV 5/10] END ....max_depth=42, n_estimators=88;, score=0.933 total time=   9.7s
# [CV 6/10] END ....max_depth=42, n_estimators=88;, score=0.930 total time=  11.0s
# [CV 7/10] END ....max_depth=42, n_estimators=88;, score=0.935 total time=  10.0s
# [CV 8/10] END ....max_depth=42, n_estimators=88;, score=0.933 total time=  10.8s
# [CV 9/10] END ....max_depth=42, n_estimators=88;, score=0.935 total time=  10.4s
# [CV 10/10] END ...max_depth=42, n_estimators=88;, score=0.935 total time=  10.5s
# [CV 1/10] END ....max_depth=54, n_estimators=63;, score=0.933 total time=   7.8s
# [CV 2/10] END ....max_depth=54, n_estimators=63;, score=0.932 total time=   7.3s
# [CV 3/10] END ....max_depth=54, n_estimators=63;, score=0.935 total time=   7.5s
# [CV 4/10] END ....max_depth=54, n_estimators=63;, score=0.931 total time=   8.1s
# [CV 5/10] END ....max_depth=54, n_estimators=63;, score=0.933 total time=   7.5s
# [CV 6/10] END ....max_depth=54, n_estimators=63;, score=0.929 total time=   7.8s
# [CV 7/10] END ....max_depth=54, n_estimators=63;, score=0.934 total time=   8.1s
# [CV 8/10] END ....max_depth=54, n_estimators=63;, score=0.933 total time=   7.2s
# [CV 9/10] END ....max_depth=54, n_estimators=63;, score=0.934 total time=   7.3s
# [CV 10/10] END ...max_depth=54, n_estimators=63;, score=0.934 total time=   8.3s
# [CV 1/10] END ...max_depth=39, n_estimators=278;, score=0.933 total time=  30.9s
# [CV 2/10] END ...max_depth=39, n_estimators=278;, score=0.932 total time=  30.5s
# [CV 3/10] END ...max_depth=39, n_estimators=278;, score=0.935 total time=  31.0s
# [CV 4/10] END ...max_depth=39, n_estimators=278;, score=0.932 total time=  31.8s
# [CV 5/10] END ...max_depth=39, n_estimators=278;, score=0.933 total time=  30.5s
# [CV 6/10] END ...max_depth=39, n_estimators=278;, score=0.930 total time=  30.8s
# [CV 7/10] END ...max_depth=39, n_estimators=278;, score=0.935 total time=  32.4s
# [CV 8/10] END ...max_depth=39, n_estimators=278;, score=0.932 total time=  30.8s
# [CV 9/10] END ...max_depth=39, n_estimators=278;, score=0.935 total time=  30.6s
# [CV 10/10] END ..max_depth=39, n_estimators=278;, score=0.935 total time=  31.5s
# [CV 1/10] END ...max_depth=35, n_estimators=282;, score=0.933 total time=  31.7s
# [CV 2/10] END ...max_depth=35, n_estimators=282;, score=0.933 total time=  30.5s
# [CV 3/10] END ...max_depth=35, n_estimators=282;, score=0.935 total time=  30.9s
# [CV 4/10] END ...max_depth=35, n_estimators=282;, score=0.932 total time=  32.3s
# [CV 5/10] END ...max_depth=35, n_estimators=282;, score=0.934 total time=  30.9s
# [CV 6/10] END ...max_depth=35, n_estimators=282;, score=0.930 total time=  30.4s
# [CV 7/10] END ...max_depth=35, n_estimators=282;, score=0.935 total time=  32.2s
# [CV 8/10] END ...max_depth=35, n_estimators=282;, score=0.933 total time=  31.8s
# [CV 9/10] END ...max_depth=35, n_estimators=282;, score=0.935 total time=  30.5s
# [CV 10/10] END ..max_depth=35, n_estimators=282;, score=0.934 total time=  31.9s
# [CV 1/10] END ....max_depth=14, n_estimators=57;, score=0.919 total time=   6.7s
# [CV 2/10] END ....max_depth=14, n_estimators=57;, score=0.916 total time=   6.0s
# [CV 3/10] END ....max_depth=14, n_estimators=57;, score=0.918 total time=   6.2s
# [CV 4/10] END ....max_depth=14, n_estimators=57;, score=0.918 total time=   5.9s
# [CV 5/10] END ....max_depth=14, n_estimators=57;, score=0.918 total time=   6.3s
# [CV 6/10] END ....max_depth=14, n_estimators=57;, score=0.914 total time=   5.9s
# [CV 7/10] END ....max_depth=14, n_estimators=57;, score=0.920 total time=   5.9s
# [CV 8/10] END ....max_depth=14, n_estimators=57;, score=0.918 total time=   6.4s
# [CV 9/10] END ....max_depth=14, n_estimators=57;, score=0.920 total time=   6.5s
# [CV 10/10] END ...max_depth=14, n_estimators=57;, score=0.919 total time=   6.1s
# [CV 1/10] END ...max_depth=16, n_estimators=164;, score=0.925 total time=  16.6s
# [CV 2/10] END ...max_depth=16, n_estimators=164;, score=0.924 total time=  17.7s
# [CV 3/10] END ...max_depth=16, n_estimators=164;, score=0.927 total time=  17.4s
# [CV 4/10] END ...max_depth=16, n_estimators=164;, score=0.925 total time=  17.4s
# [CV 5/10] END ...max_depth=16, n_estimators=164;, score=0.924 total time=  16.9s
# [CV 6/10] END ...max_depth=16, n_estimators=164;, score=0.921 total time=  17.9s
# [CV 7/10] END ...max_depth=16, n_estimators=164;, score=0.926 total time=  17.3s
# [CV 8/10] END ...max_depth=16, n_estimators=164;, score=0.925 total time=  16.9s
# [CV 9/10] END ...max_depth=16, n_estimators=164;, score=0.927 total time=  17.2s
# [CV 10/10] END ..max_depth=16, n_estimators=164;, score=0.925 total time=  17.4s
# [CV 1/10] END ...max_depth=53, n_estimators=139;, score=0.933 total time=  15.5s
# [CV 2/10] END ...max_depth=53, n_estimators=139;, score=0.932 total time=  15.5s
# [CV 3/10] END ...max_depth=53, n_estimators=139;, score=0.936 total time=  16.0s
# [CV 4/10] END ...max_depth=53, n_estimators=139;, score=0.932 total time=  15.6s
# [CV 5/10] END ...max_depth=53, n_estimators=139;, score=0.934 total time=  16.0s
# [CV 6/10] END ...max_depth=53, n_estimators=139;, score=0.929 total time=  16.1s
# [CV 7/10] END ...max_depth=53, n_estimators=139;, score=0.934 total time=  15.5s
# [CV 8/10] END ...max_depth=53, n_estimators=139;, score=0.933 total time=  15.8s
# [CV 9/10] END ...max_depth=53, n_estimators=139;, score=0.935 total time=  16.1s
# [CV 10/10] END ..max_depth=53, n_estimators=139;, score=0.935 total time=  15.5s
# [CV 1/10] END ...max_depth=34, n_estimators=148;, score=0.933 total time=  16.9s
# [CV 2/10] END ...max_depth=34, n_estimators=148;, score=0.933 total time=  17.3s
# [CV 3/10] END ...max_depth=34, n_estimators=148;, score=0.935 total time=  16.8s
# [CV 4/10] END ...max_depth=34, n_estimators=148;, score=0.932 total time=  16.9s
# [CV 5/10] END ...max_depth=34, n_estimators=148;, score=0.933 total time=  17.5s
# [CV 6/10] END ...max_depth=34, n_estimators=148;, score=0.930 total time=  17.3s
# [CV 7/10] END ...max_depth=34, n_estimators=148;, score=0.935 total time=  16.5s
# [CV 8/10] END ...max_depth=34, n_estimators=148;, score=0.933 total time=  17.5s
# [CV 9/10] END ...max_depth=34, n_estimators=148;, score=0.935 total time=  17.3s
# [CV 10/10] END ..max_depth=34, n_estimators=148;, score=0.934 total time=  16.9s
# [CV 1/10] END ...max_depth=29, n_estimators=117;, score=0.934 total time=  13.5s
# [CV 2/10] END ...max_depth=29, n_estimators=117;, score=0.933 total time=  14.3s
# [CV 3/10] END ...max_depth=29, n_estimators=117;, score=0.936 total time=  13.0s
# [CV 4/10] END ...max_depth=29, n_estimators=117;, score=0.933 total time=  13.9s
# [CV 7/10] END ...max_depth=11, n_estimators=132;, score=0.899 total time=  12.5s
# [CV 8/10] END ...max_depth=11, n_estimators=132;, score=0.900 total time=  11.9s
# [CV 9/10] END ...max_depth=11, n_estimators=132;, score=0.902 total time=  11.5s
# [CV 10/10] END ..max_depth=11, n_estimators=132;, score=0.899 total time=  12.5s
# [CV 1/10] END ...max_depth=49, n_estimators=105;, score=0.933 total time=  11.8s
# [CV 2/10] END ...max_depth=49, n_estimators=105;, score=0.932 total time=  12.7s
# [CV 3/10] END ...max_depth=49, n_estimators=105;, score=0.936 total time=  11.7s
# [CV 4/10] END ...max_depth=49, n_estimators=105;, score=0.932 total time=  12.9s
# [CV 5/10] END ...max_depth=49, n_estimators=105;, score=0.933 total time=  11.9s
# [CV 6/10] END ...max_depth=49, n_estimators=105;, score=0.930 total time=  12.7s
# [CV 7/10] END ...max_depth=49, n_estimators=105;, score=0.935 total time=  11.8s
# [CV 8/10] END ...max_depth=49, n_estimators=105;, score=0.933 total time=  12.4s
# [CV 9/10] END ...max_depth=49, n_estimators=105;, score=0.934 total time=  11.9s
# [CV 10/10] END ..max_depth=49, n_estimators=105;, score=0.934 total time=  12.6s
# [CV 1/10] END ...max_depth=22, n_estimators=278;, score=0.935 total time=  30.3s
# [CV 2/10] END ...max_depth=22, n_estimators=278;, score=0.934 total time=  30.5s
# [CV 3/10] END ...max_depth=22, n_estimators=278;, score=0.937 total time=  31.6s
# [CV 4/10] END ...max_depth=22, n_estimators=278;, score=0.934 total time=  30.2s
# [CV 5/10] END ...max_depth=22, n_estimators=278;, score=0.935 total time=  29.9s
# [CV 6/10] END ...max_depth=22, n_estimators=278;, score=0.931 total time=  31.0s
# [CV 7/10] END ...max_depth=22, n_estimators=278;, score=0.936 total time=  31.2s
# [CV 8/10] END ...max_depth=22, n_estimators=278;, score=0.935 total time=  29.8s
# [CV 9/10] END ...max_depth=22, n_estimators=278;, score=0.936 total time=  30.2s
# [CV 10/10] END ..max_depth=22, n_estimators=278;, score=0.936 total time=  31.4s
# [CV 1/10] END ...max_depth=46, n_estimators=119;, score=0.933 total time=  13.9s
# [CV 2/10] END ...max_depth=46, n_estimators=119;, score=0.933 total time=  14.3s
# [CV 3/10] END ...max_depth=46, n_estimators=119;, score=0.935 total time=  13.3s
# [CV 4/10] END ...max_depth=46, n_estimators=119;, score=0.932 total time=  14.1s
# [CV 5/10] END ...max_depth=46, n_estimators=119;, score=0.933 total time=  13.4s
# [CV 6/10] END ...max_depth=46, n_estimators=119;, score=0.930 total time=  14.1s
# [CV 7/10] END ...max_depth=46, n_estimators=119;, score=0.934 total time=  14.9s
# [CV 8/10] END ...max_depth=46, n_estimators=119;, score=0.933 total time=  14.1s
# [CV 9/10] END ...max_depth=46, n_estimators=119;, score=0.935 total time=  14.8s
# [CV 10/10] END ..max_depth=46, n_estimators=119;, score=0.934 total time=  13.6s
# [CV 1/10] END ...max_depth=26, n_estimators=293;, score=0.934 total time=  33.0s
# [CV 2/10] END ...max_depth=26, n_estimators=293;, score=0.934 total time=  31.8s
# [CV 8/10] END ...max_depth=12, n_estimators=107;, score=0.905 total time=  10.3s
# [CV 9/10] END ...max_depth=12, n_estimators=107;, score=0.911 total time=   9.7s
# [CV 10/10] END ..max_depth=12, n_estimators=107;, score=0.907 total time=  10.0s
# [CV 1/10] END ...max_depth=24, n_estimators=231;, score=0.935 total time=  25.7s
# [CV 2/10] END ...max_depth=24, n_estimators=231;, score=0.934 total time=  26.2s
# [CV 3/10] END ...max_depth=24, n_estimators=231;, score=0.937 total time=  26.2s
# [CV 4/10] END ...max_depth=24, n_estimators=231;, score=0.934 total time=  25.6s
# [CV 5/10] END ...max_depth=24, n_estimators=231;, score=0.935 total time=  25.1s
# [CV 6/10] END ...max_depth=24, n_estimators=231;, score=0.931 total time=  25.8s
# [CV 7/10] END ...max_depth=24, n_estimators=231;, score=0.936 total time=  25.4s
# [CV 8/10] END ...max_depth=24, n_estimators=231;, score=0.934 total time=  25.1s
# [CV 9/10] END ...max_depth=24, n_estimators=231;, score=0.936 total time=  25.2s
# [CV 10/10] END ..max_depth=24, n_estimators=231;, score=0.936 total time=  25.3s
# [CV 1/10] END ...max_depth=46, n_estimators=183;, score=0.933 total time=  20.7s
# [CV 2/10] END ...max_depth=46, n_estimators=183;, score=0.932 total time=  20.6s
# [CV 3/10] END ...max_depth=46, n_estimators=183;, score=0.935 total time=  20.3s
# [CV 4/10] END ...max_depth=46, n_estimators=183;, score=0.933 total time=  20.5s
# [CV 5/10] END ...max_depth=46, n_estimators=183;, score=0.933 total time=  20.8s
# [CV 6/10] END ...max_depth=46, n_estimators=183;, score=0.929 total time=  21.0s
# [CV 7/10] END ...max_depth=46, n_estimators=183;, score=0.934 total time=  20.5s
# [CV 8/10] END ...max_depth=46, n_estimators=183;, score=0.932 total time=  20.5s
# [CV 9/10] END ...max_depth=46, n_estimators=183;, score=0.935 total time=  20.7s
# [CV 10/10] END ..max_depth=46, n_estimators=183;, score=0.934 total time=  20.5s
# [CV 1/10] END ....max_depth=14, n_estimators=50;, score=0.919 total time=   5.9s
# [CV 2/10] END ....max_depth=14, n_estimators=50;, score=0.917 total time=   5.3s
# [CV 3/10] END ....max_depth=14, n_estimators=50;, score=0.920 total time=   5.4s
# [CV 4/10] END ....max_depth=14, n_estimators=50;, score=0.918 total time=   5.4s
# [CV 5/10] END ....max_depth=14, n_estimators=50;, score=0.917 total time=   5.3s
# [CV 6/10] END ....max_depth=14, n_estimators=50;, score=0.915 total time=   5.5s
# [CV 7/10] END ....max_depth=14, n_estimators=50;, score=0.919 total time=   5.4s
# [CV 8/10] END ....max_depth=14, n_estimators=50;, score=0.918 total time=   5.4s
# [CV 9/10] END ....max_depth=14, n_estimators=50;, score=0.921 total time=   5.4s
# [CV 10/10] END ...max_depth=14, n_estimators=50;, score=0.918 total time=   5.4s
# [CV 1/10] END ...max_depth=18, n_estimators=135;, score=0.931 total time=  13.9s
# [CV 2/10] END ...max_depth=18, n_estimators=135;, score=0.929 total time=  15.0s
# [CV 3/10] END ...max_depth=18, n_estimators=135;, score=0.933 total time=  14.8s
# [CV 10/10] END ..max_depth=22, n_estimators=245;, score=0.936 total time=  26.9s
# [CV 1/10] END ....max_depth=48, n_estimators=69;, score=0.932 total time=   8.0s
# [CV 2/10] END ....max_depth=48, n_estimators=69;, score=0.932 total time=   7.9s
# [CV 3/10] END ....max_depth=48, n_estimators=69;, score=0.935 total time=   8.2s
# [CV 4/10] END ....max_depth=48, n_estimators=69;, score=0.931 total time=   9.0s
# [CV 5/10] END ....max_depth=48, n_estimators=69;, score=0.932 total time=   8.1s
# [CV 6/10] END ....max_depth=48, n_estimators=69;, score=0.929 total time=   8.4s
# [CV 7/10] END ....max_depth=48, n_estimators=69;, score=0.934 total time=   8.8s
# [CV 8/10] END ....max_depth=48, n_estimators=69;, score=0.932 total time=   8.1s
# [CV 9/10] END ....max_depth=48, n_estimators=69;, score=0.935 total time=   8.0s
# [CV 10/10] END ...max_depth=48, n_estimators=69;, score=0.934 total time=   8.5s
# [CV 1/10] END ...max_depth=24, n_estimators=246;, score=0.934 total time=  27.4s
# [CV 2/10] END ...max_depth=24, n_estimators=246;, score=0.934 total time=  26.9s
# [CV 3/10] END ...max_depth=24, n_estimators=246;, score=0.937 total time=  26.6s
# [CV 4/10] END ...max_depth=24, n_estimators=246;, score=0.935 total time=  26.4s
# [CV 5/10] END ...max_depth=24, n_estimators=246;, score=0.935 total time=  27.4s
# [CV 6/10] END ...max_depth=24, n_estimators=246;, score=0.932 total time=  27.2s
# [CV 7/10] END ...max_depth=24, n_estimators=246;, score=0.936 total time=  27.4s
# [CV 8/10] END ...max_depth=24, n_estimators=246;, score=0.934 total time=  26.7s
# [CV 9/10] END ...max_depth=24, n_estimators=246;, score=0.936 total time=  26.8s
# [CV 10/10] END ..max_depth=24, n_estimators=246;, score=0.936 total time=  26.4s
# [CV 1/10] END ...max_depth=40, n_estimators=177;, score=0.933 total time=  20.0s
# [CV 2/10] END ...max_depth=40, n_estimators=177;, score=0.933 total time=  20.2s
# [CV 3/10] END ...max_depth=40, n_estimators=177;, score=0.936 total time=  19.6s
# [CV 4/10] END ...max_depth=40, n_estimators=177;, score=0.932 total time=  19.8s
# [CV 5/10] END ...max_depth=40, n_estimators=177;, score=0.933 total time=  20.1s
# [CV 6/10] END ...max_depth=40, n_estimators=177;, score=0.930 total time=  20.0s
# [CV 7/10] END ...max_depth=40, n_estimators=177;, score=0.935 total time=  19.4s
# [CV 8/10] END ...max_depth=40, n_estimators=177;, score=0.932 total time=  21.1s
# [CV 9/10] END ...max_depth=40, n_estimators=177;, score=0.935 total time=  20.1s
# [CV 10/10] END ..max_depth=40, n_estimators=177;, score=0.934 total time=  21.3s
# [CV 1/10] END ...max_depth=25, n_estimators=236;, score=0.935 total time=  27.0s
# [CV 2/10] END ...max_depth=25, n_estimators=236;, score=0.934 total time=  25.8s
# [CV 3/10] END ...max_depth=25, n_estimators=236;, score=0.937 total time=  26.9s
# [CV 4/10] END ...max_depth=25, n_estimators=236;, score=0.934 total time=  26.2s
# [CV 5/10] END ...max_depth=25, n_estimators=236;, score=0.935 total time=  25.7s
# [CV 6/10] END ...max_depth=25, n_estimators=236;, score=0.932 total time=  26.5s
# [CV 7/10] END ...max_depth=25, n_estimators=236;, score=0.936 total time=  29.0s
# [CV 8/10] END ...max_depth=25, n_estimators=236;, score=0.934 total time=  27.1s
# [CV 9/10] END ...max_depth=25, n_estimators=236;, score=0.936 total time=  27.3s
# [CV 10/10] END ..max_depth=25, n_estimators=236;, score=0.936 total time=  27.4s
# [CV 1/10] END ....max_depth=47, n_estimators=26;, score=0.932 total time=   3.8s
# [CV 2/10] END ....max_depth=47, n_estimators=26;, score=0.931 total time=   3.8s
# [CV 3/10] END ....max_depth=47, n_estimators=26;, score=0.934 total time=   3.6s
# [CV 4/10] END ....max_depth=47, n_estimators=26;, score=0.931 total time=   3.6s
# [CV 5/10] END ....max_depth=47, n_estimators=26;, score=0.932 total time=   3.5s
# [CV 6/10] END ....max_depth=47, n_estimators=26;, score=0.929 total time=   3.4s
# [CV 7/10] END ....max_depth=47, n_estimators=26;, score=0.933 total time=   3.6s
# [CV 8/10] END ....max_depth=47, n_estimators=26;, score=0.931 total time=   3.6s
# [CV 9/10] END ....max_depth=47, n_estimators=26;, score=0.933 total time=   3.5s
# [CV 10/10] END ...max_depth=47, n_estimators=26;, score=0.935 total time=   3.5s
# [CV 1/10] END ...max_depth=14, n_estimators=203;, score=0.919 total time=  21.0s
# [CV 2/10] END ...max_depth=14, n_estimators=203;, score=0.917 total time=  21.4s
# [CV 3/10] END ...max_depth=14, n_estimators=203;, score=0.921 total time=  19.6s
# [CV 4/10] END ...max_depth=14, n_estimators=203;, score=0.918 total time=  19.7s
# [CV 5/10] END ...max_depth=14, n_estimators=203;, score=0.918 total time=  20.1s
# [CV 6/10] END ...max_depth=14, n_estimators=203;, score=0.915 total time=  19.9s
# [CV 7/10] END ...max_depth=14, n_estimators=203;, score=0.920 total time=  19.3s
# [CV 8/10] END ...max_depth=14, n_estimators=203;, score=0.918 total time=  19.8s
# [CV 9/10] END ...max_depth=14, n_estimators=203;, score=0.921 total time=  20.2s
# [CV 10/10] END ..max_depth=14, n_estimators=203;, score=0.918 total time=  19.9s
# [CV 1/10] END ...max_depth=37, n_estimators=176;, score=0.933 total time=  19.5s
# [CV 2/10] END ...max_depth=37, n_estimators=176;, score=0.933 total time=  19.8s
# [CV 3/10] END ...max_depth=37, n_estimators=176;, score=0.936 total time=  19.9s
# [CV 4/10] END ...max_depth=37, n_estimators=176;, score=0.933 total time=  19.7s
# [CV 5/10] END ...max_depth=37, n_estimators=176;, score=0.933 total time=  19.9s
# [CV 6/10] END ...max_depth=37, n_estimators=176;, score=0.930 total time=  19.7s
# [CV 7/10] END ...max_depth=37, n_estimators=176;, score=0.935 total time=  20.1s
# [CV 8/10] END ...max_depth=37, n_estimators=176;, score=0.933 total time=  20.8s
# [CV 9/10] END ...max_depth=37, n_estimators=176;, score=0.935 total time=  20.2s
# [CV 10/10] END ..max_depth=37, n_estimators=176;, score=0.935 total time=  19.8s
# [CV 4/10] END ...max_depth=14, n_estimators=207;, score=0.918 total time=  20.5s
# [CV 5/10] END ...max_depth=14, n_estimators=207;, score=0.918 total time=  20.0s
# [CV 6/10] END ...max_depth=14, n_estimators=207;, score=0.914 total time=  20.0s
# [CV 7/10] END ...max_depth=14, n_estimators=207;, score=0.920 total time=  20.1s
# [CV 8/10] END ...max_depth=14, n_estimators=207;, score=0.918 total time=  20.1s
# [CV 9/10] END ...max_depth=14, n_estimators=207;, score=0.921 total time=  20.0s
# [CV 10/10] END ..max_depth=14, n_estimators=207;, score=0.918 total time=  20.0s
# [CV 1/10] END ....max_depth=37, n_estimators=98;, score=0.933 total time=  11.8s
# [CV 2/10] END ....max_depth=37, n_estimators=98;, score=0.932 total time=  11.2s
# [CV 3/10] END ....max_depth=37, n_estimators=98;, score=0.935 total time=  11.9s
# [CV 4/10] END ....max_depth=37, n_estimators=98;, score=0.932 total time=  11.3s
# [CV 5/10] END ....max_depth=37, n_estimators=98;, score=0.933 total time=  12.1s
# [CV 6/10] END ....max_depth=37, n_estimators=98;, score=0.930 total time=  10.9s
# [CV 7/10] END ....max_depth=37, n_estimators=98;, score=0.934 total time=  12.1s
# [CV 8/10] END ....max_depth=37, n_estimators=98;, score=0.933 total time=  11.2s
# [CV 9/10] END ....max_depth=37, n_estimators=98;, score=0.934 total time=  12.1s
# [CV 10/10] END ...max_depth=37, n_estimators=98;, score=0.934 total time=  10.7s
# [CV 1/10] END ...max_depth=47, n_estimators=255;, score=0.933 total time=  28.2s
# [CV 2/10] END ...max_depth=47, n_estimators=255;, score=0.933 total time=  29.5s
# [CV 3/10] END ...max_depth=47, n_estimators=255;, score=0.936 total time=  28.7s
# [CV 4/10] END ...max_depth=47, n_estimators=255;, score=0.933 total time=  27.7s
# [CV 5/10] END ...max_depth=47, n_estimators=255;, score=0.933 total time=  27.8s
# [CV 6/10] END ...max_depth=47, n_estimators=255;, score=0.930 total time=  27.7s
# [CV 7/10] END ...max_depth=47, n_estimators=255;, score=0.934 total time=  28.8s
# [CV 8/10] END ...max_depth=47, n_estimators=255;, score=0.932 total time=  29.2s
# [CV 9/10] END ...max_depth=47, n_estimators=255;, score=0.935 total time=  28.1s
# [CV 10/10] END ..max_depth=47, n_estimators=255;, score=0.934 total time=  27.9s
# [CV 1/10] END ...max_depth=28, n_estimators=215;, score=0.934 total time=  23.7s
# [CV 2/10] END ...max_depth=28, n_estimators=215;, score=0.933 total time=  23.7s
# [CV 3/10] END ...max_depth=28, n_estimators=215;, score=0.936 total time=  23.5s
# [CV 4/10] END ...max_depth=28, n_estimators=215;, score=0.934 total time=  24.0s
# [CV 5/10] END ...max_depth=28, n_estimators=215;, score=0.934 total time=  23.7s
# [CV 6/10] END ...max_depth=28, n_estimators=215;, score=0.931 total time=  23.6s
# [CV 7/10] END ...max_depth=28, n_estimators=215;, score=0.935 total time=  23.8s
# [CV 8/10] END ...max_depth=28, n_estimators=215;, score=0.933 total time=  23.5s
# [CV 9/10] END ...max_depth=28, n_estimators=215;, score=0.936 total time=  23.7s
# [CV 10/10] END ..max_depth=28, n_estimators=215;, score=0.936 total time=  23.6s
# [CV 1/10] END ...max_depth=20, n_estimators=145;, score=0.934 total time=  15.5s
# [CV 2/10] END ...max_depth=20, n_estimators=145;, score=0.932 total time=  16.2s
# [CV 3/10] END ...max_depth=20, n_estimators=145;, score=0.935 total time=  16.5s
# [CV 4/10] END ...max_depth=20, n_estimators=145;, score=0.933 total time=  15.8s
# [CV 5/10] END ...max_depth=20, n_estimators=145;, score=0.934 total time=  16.2s
# [CV 6/10] END ...max_depth=20, n_estimators=145;, score=0.930 total time=  16.4s
# [CV 7/10] END ...max_depth=20, n_estimators=145;, score=0.935 total time=  15.7s
# [CV 8/10] END ...max_depth=20, n_estimators=145;, score=0.932 total time=  16.2s
# [CV 9/10] END ...max_depth=20, n_estimators=145;, score=0.935 total time=  16.1s
# [CV 10/10] END ..max_depth=20, n_estimators=145;, score=0.934 total time=  15.6s
# [CV 1/10] END ....max_depth=24, n_estimators=67;, score=0.934 total time=   8.8s
# [CV 2/10] END ....max_depth=24, n_estimators=67;, score=0.934 total time=   7.6s
# [CV 3/10] END ....max_depth=24, n_estimators=67;, score=0.936 total time=   7.7s
# [CV 4/10] END ....max_depth=24, n_estimators=67;, score=0.934 total time=   7.9s
# [CV 5/10] END ....max_depth=24, n_estimators=67;, score=0.935 total time=   9.0s
# [CV 6/10] END ....max_depth=24, n_estimators=67;, score=0.930 total time=   7.6s
# [CV 7/10] END ....max_depth=24, n_estimators=67;, score=0.936 total time=   7.8s
# [CV 8/10] END ....max_depth=24, n_estimators=67;, score=0.934 total time=   7.9s
# [CV 9/10] END ....max_depth=24, n_estimators=67;, score=0.936 total time=   8.7s
# [CV 10/10] END ...max_depth=24, n_estimators=67;, score=0.936 total time=   7.6s
# [CV 1/10] END ...max_depth=46, n_estimators=155;, score=0.933 total time=  16.9s
# [CV 2/10] END ...max_depth=46, n_estimators=155;, score=0.933 total time=  17.5s
# [CV 3/10] END ...max_depth=46, n_estimators=155;, score=0.935 total time=  17.6s
# [CV 4/10] END ...max_depth=46, n_estimators=155;, score=0.932 total time=  17.4s
# [CV 5/10] END ...max_depth=46, n_estimators=155;, score=0.933 total time=  16.7s
# [CV 6/10] END ...max_depth=46, n_estimators=155;, score=0.929 total time=  17.6s
# [CV 7/10] END ...max_depth=46, n_estimators=155;, score=0.935 total time=  17.6s
# [CV 8/10] END ...max_depth=46, n_estimators=155;, score=0.933 total time=  17.1s
# [CV 9/10] END ...max_depth=46, n_estimators=155;, score=0.935 total time=  17.3s
# [CV 10/10] END ..max_depth=46, n_estimators=155;, score=0.934 total time=  17.6s
# [CV 1/10] END ...max_depth=41, n_estimators=162;, score=0.933 total time=  18.6s
# [CV 2/10] END ...max_depth=41, n_estimators=162;, score=0.933 total time=  18.0s
# [CV 3/10] END ...max_depth=41, n_estimators=162;, score=0.935 total time=  18.5s
# [CV 4/10] END ...max_depth=41, n_estimators=162;, score=0.933 total time=  18.9s
# [CV 5/10] END ...max_depth=41, n_estimators=162;, score=0.933 total time=  18.6s
# [CV 6/10] END ...max_depth=41, n_estimators=162;, score=0.930 total time=  18.1s
# [CV 7/10] END ...max_depth=41, n_estimators=162;, score=0.935 total time=  18.2s
# [CV 8/10] END ...max_depth=41, n_estimators=162;, score=0.932 total time=  18.5s
# [CV 9/10] END ...max_depth=41, n_estimators=162;, score=0.935 total time=  18.5s
# [CV 10/10] END ..max_depth=41, n_estimators=162;, score=0.935 total time=  18.3s
# [CV 1/10] END ...max_depth=40, n_estimators=241;, score=0.934 total time=  27.0s
# [CV 2/10] END ...max_depth=40, n_estimators=241;, score=0.932 total time=  26.5s
# [CV 3/10] END ...max_depth=40, n_estimators=241;, score=0.935 total time=  26.6s
# [CV 4/10] END ...max_depth=40, n_estimators=241;, score=0.933 total time=  26.4s
# [CV 5/10] END ...max_depth=40, n_estimators=241;, score=0.933 total time=  26.6s
# [CV 6/10] END ...max_depth=40, n_estimators=241;, score=0.930 total time=  26.9s
# [CV 7/10] END ...max_depth=40, n_estimators=241;, score=0.934 total time=  26.4s
# [CV 8/10] END ...max_depth=40, n_estimators=241;, score=0.933 total time=  27.4s
# [CV 9/10] END ...max_depth=40, n_estimators=241;, score=0.935 total time=  27.7s
# [CV 10/10] END ..max_depth=40, n_estimators=241;, score=0.935 total time=  27.8s
# [CV 1/10] END ...max_depth=51, n_estimators=211;, score=0.933 total time=  23.6s
# [CV 2/10] END ...max_depth=51, n_estimators=211;, score=0.933 total time=  23.7s
# [CV 3/10] END ...max_depth=51, n_estimators=211;, score=0.935 total time=  23.3s
# [CV 4/10] END ...max_depth=51, n_estimators=211;, score=0.933 total time=  24.1s
# [CV 5/10] END ...max_depth=51, n_estimators=211;, score=0.934 total time=  23.8s
# [CV 6/10] END ...max_depth=51, n_estimators=211;, score=0.930 total time=  23.9s
# [CV 7/10] END ...max_depth=51, n_estimators=211;, score=0.935 total time=  24.0s
# [CV 8/10] END ...max_depth=51, n_estimators=211;, score=0.933 total time=  24.1s
# [CV 9/10] END ...max_depth=51, n_estimators=211;, score=0.935 total time=  24.2s
# [CV 10/10] END ..max_depth=51, n_estimators=211;, score=0.935 total time=  24.1s
# [CV 1/10] END ...max_depth=49, n_estimators=115;, score=0.933 total time=  13.0s
# [CV 2/10] END ...max_depth=49, n_estimators=115;, score=0.932 total time=  13.7s
# [CV 3/10] END ...max_depth=49, n_estimators=115;, score=0.935 total time=  12.7s
# [CV 4/10] END ...max_depth=49, n_estimators=115;, score=0.932 total time=  13.9s
# [CV 5/10] END ...max_depth=49, n_estimators=115;, score=0.934 total time=  12.9s
# [CV 6/10] END ...max_depth=49, n_estimators=115;, score=0.930 total time=  13.7s
# [CV 7/10] END ...max_depth=49, n_estimators=115;, score=0.935 total time=  13.2s
# [CV 8/10] END ...max_depth=49, n_estimators=115;, score=0.932 total time=  13.4s
# [CV 9/10] END ...max_depth=49, n_estimators=115;, score=0.934 total time=  13.9s
# [CV 10/10] END ..max_depth=49, n_estimators=115;, score=0.934 total time=  13.1s
# [CV 1/10] END ...max_depth=28, n_estimators=275;, score=0.934 total time=  30.0s
# [CV 8/10] END ...max_depth=10, n_estimators=161;, score=0.892 total time=  13.2s
# [CV 9/10] END ...max_depth=10, n_estimators=161;, score=0.893 total time=  14.1s
# [CV 10/10] END ..max_depth=10, n_estimators=161;, score=0.890 total time=  13.3s
# [CV 1/10] END ...max_depth=40, n_estimators=148;, score=0.933 total time=  16.5s
# [CV 2/10] END ...max_depth=40, n_estimators=148;, score=0.933 total time=  17.8s
# [CV 3/10] END ...max_depth=40, n_estimators=148;, score=0.935 total time=  16.9s
# [CV 4/10] END ...max_depth=40, n_estimators=148;, score=0.932 total time=  16.5s
# [CV 5/10] END ...max_depth=40, n_estimators=148;, score=0.933 total time=  17.0s
# [CV 6/10] END ...max_depth=40, n_estimators=148;, score=0.930 total time=  17.3s
# [CV 7/10] END ...max_depth=40, n_estimators=148;, score=0.935 total time=  16.4s
# [CV 8/10] END ...max_depth=40, n_estimators=148;, score=0.933 total time=  16.8s
# [CV 9/10] END ...max_depth=40, n_estimators=148;, score=0.935 total time=  16.8s
# [CV 10/10] END ..max_depth=40, n_estimators=148;, score=0.934 total time=  16.2s
# [CV 1/10] END ...max_depth=41, n_estimators=177;, score=0.933 total time=  19.6s
# [CV 2/10] END ...max_depth=41, n_estimators=177;, score=0.933 total time=  20.3s
# [CV 3/10] END ...max_depth=41, n_estimators=177;, score=0.935 total time=  19.8s
# [CV 4/10] END ...max_depth=41, n_estimators=177;, score=0.933 total time=  19.7s
# [CV 5/10] END ...max_depth=41, n_estimators=177;, score=0.934 total time=  19.8s
# [CV 6/10] END ...max_depth=41, n_estimators=177;, score=0.930 total time=  19.7s
# [CV 7/10] END ...max_depth=41, n_estimators=177;, score=0.935 total time=  20.3s
# [CV 8/10] END ...max_depth=41, n_estimators=177;, score=0.932 total time=  21.3s
# [CV 9/10] END ...max_depth=41, n_estimators=177;, score=0.935 total time=  21.6s
# [CV 10/10] END ..max_depth=41, n_estimators=177;, score=0.935 total time=  20.9s
# [CV 1/10] END ...max_depth=19, n_estimators=104;, score=0.932 total time=  12.0s
# [CV 2/10] END ...max_depth=19, n_estimators=104;, score=0.931 total time=  12.1s
# [CV 3/10] END ...max_depth=19, n_estimators=104;, score=0.934 total time=  11.0s
# [CV 4/10] END ...max_depth=19, n_estimators=104;, score=0.931 total time=  11.9s
# [CV 5/10] END ...max_depth=19, n_estimators=104;, score=0.932 total time=  11.1s
# [CV 6/10] END ...max_depth=19, n_estimators=104;, score=0.929 total time=  12.4s
# [CV 7/10] END ...max_depth=19, n_estimators=104;, score=0.933 total time=  11.0s
# [CV 8/10] END ...max_depth=19, n_estimators=104;, score=0.931 total time=  11.9s
# [CV 9/10] END ...max_depth=19, n_estimators=104;, score=0.933 total time=  11.1s
# [CV 10/10] END ..max_depth=19, n_estimators=104;, score=0.933 total time=  12.2s
# [CV 1/10] END ....max_depth=49, n_estimators=35;, score=0.932 total time=   4.6s
# [CV 2/10] END ....max_depth=49, n_estimators=35;, score=0.931 total time=   4.6s
# [CV 3/10] END ....max_depth=49, n_estimators=35;, score=0.935 total time=   4.6s
# [CV 4/10] END ....max_depth=49, n_estimators=35;, score=0.931 total time=   4.6s
# [CV 5/10] END ....max_depth=49, n_estimators=35;, score=0.932 total time=   4.5s
# [CV 6/10] END ....max_depth=49, n_estimators=35;, score=0.929 total time=   4.6s
# [CV 7/10] END ....max_depth=49, n_estimators=35;, score=0.933 total time=   4.5s
# [CV 8/10] END ....max_depth=49, n_estimators=35;, score=0.932 total time=   5.2s
# [CV 9/10] END ....max_depth=49, n_estimators=35;, score=0.934 total time=   5.5s
# [CV 10/10] END ...max_depth=49, n_estimators=35;, score=0.933 total time=   5.2s
# RandomizedSearchCV(cv=10, estimator=RandomForestClassifier(n_jobs=-1),
#                    n_iter=100,
#                    param_distributions={'max_depth': <scipy.stats._distn_infrastructure.rv_discrete_frozen object at 0x0000025ECA30FB30>,
#                                         'n_estimators': <scipy.stats._distn_infrastructure.rv_discrete_frozen object at 0x0000025EAC1FF320>},
#                    scoring='f1_weighted', verbose=3)

# %%
rnd_search.best_params_
# Out:
# {'max_depth': 24, 'n_estimators': 246}

# %%
rnd_search.best_estimator_
# Out:
# RandomForestClassifier(max_depth=24, n_estimators=246, n_jobs=-1)

# %%
cvres = rnd_search.cv_results_
# Ordenar por "mean_test_score" de manera descendente
sorted_results = sorted(zip(cvres["mean_test_score"], cvres["params"]), reverse=True)

# Imprimir los resultados ordenados
for mean_score, params in sorted_results:
    print("F1 score:", mean_score, "-", "Parámetros:", params)
# Out:
# F1 score: 0.9348872195310125 - Parámetros: {'max_depth': 24, 'n_estimators': 246}
# F1 score: 0.9348620332791269 - Parámetros: {'max_depth': 24, 'n_estimators': 231}
# F1 score: 0.9348263945077239 - Parámetros: {'max_depth': 25, 'n_estimators': 236}
# F1 score: 0.9348167584075986 - Parámetros: {'max_depth': 22, 'n_estimators': 278}
# F1 score: 0.9347281627912603 - Parámetros: {'max_depth': 22, 'n_estimators': 245}
# F1 score: 0.9347023978054908 - Parámetros: {'max_depth': 23, 'n_estimators': 112}
# F1 score: 0.9346662811958222 - Parámetros: {'max_depth': 26, 'n_estimators': 287}
# F1 score: 0.9346657536706197 - Parámetros: {'max_depth': 24, 'n_estimators': 98}
# F1 score: 0.9346330188177525 - Parámetros: {'max_depth': 26, 'n_estimators': 293}
# F1 score: 0.9345647219136227 - Parámetros: {'max_depth': 25, 'n_estimators': 234}
# F1 score: 0.934541211152038 - Parámetros: {'max_depth': 25, 'n_estimators': 206}
# F1 score: 0.9344859021862767 - Parámetros: {'max_depth': 27, 'n_estimators': 279}
# F1 score: 0.9344293061008901 - Parámetros: {'max_depth': 24, 'n_estimators': 67}
# F1 score: 0.9343933816916301 - Parámetros: {'max_depth': 28, 'n_estimators': 275}
# F1 score: 0.9342696590953212 - Parámetros: {'max_depth': 28, 'n_estimators': 215}
# F1 score: 0.9340752163378214 - Parámetros: {'max_depth': 30, 'n_estimators': 275}
# F1 score: 0.9339741233457902 - Parámetros: {'max_depth': 29, 'n_estimators': 207}
# F1 score: 0.9339098431673765 - Parámetros: {'max_depth': 30, 'n_estimators': 270}
# F1 score: 0.9338578786103943 - Parámetros: {'max_depth': 29, 'n_estimators': 117}
# F1 score: 0.933785770392338 - Parámetros: {'max_depth': 30, 'n_estimators': 121}
# F1 score: 0.9335595910978121 - Parámetros: {'max_depth': 37, 'n_estimators': 176}
# F1 score: 0.9335473589002368 - Parámetros: {'max_depth': 35, 'n_estimators': 277}
# F1 score: 0.9335460045261623 - Parámetros: {'max_depth': 40, 'n_estimators': 213}
# F1 score: 0.9335047368389748 - Parámetros: {'max_depth': 22, 'n_estimators': 29}
# F1 score: 0.9334896466573162 - Parámetros: {'max_depth': 33, 'n_estimators': 190}
# F1 score: 0.9334516025449663 - Parámetros: {'max_depth': 41, 'n_estimators': 177}
# F1 score: 0.9334451032679807 - Parámetros: {'max_depth': 42, 'n_estimators': 281}
# F1 score: 0.9334409803728209 - Parámetros: {'max_depth': 52, 'n_estimators': 286}
# F1 score: 0.9334315680773951 - Parámetros: {'max_depth': 54, 'n_estimators': 233}
# F1 score: 0.9334072519570078 - Parámetros: {'max_depth': 51, 'n_estimators': 211}
# F1 score: 0.9334011797170797 - Parámetros: {'max_depth': 39, 'n_estimators': 278}
# F1 score: 0.9333993538478215 - Parámetros: {'max_depth': 37, 'n_estimators': 210}
# F1 score: 0.9333870604476177 - Parámetros: {'max_depth': 20, 'n_estimators': 145}
# F1 score: 0.9333696611466132 - Parámetros: {'max_depth': 36, 'n_estimators': 137}
# F1 score: 0.9333640188080994 - Parámetros: {'max_depth': 20, 'n_estimators': 86}
# F1 score: 0.9333544535219728 - Parámetros: {'max_depth': 41, 'n_estimators': 162}
# F1 score: 0.9333454233119844 - Parámetros: {'max_depth': 35, 'n_estimators': 282}
# F1 score: 0.9333441562336532 - Parámetros: {'max_depth': 35, 'n_estimators': 112}
# F1 score: 0.9333423373376479 - Parámetros: {'max_depth': 53, 'n_estimators': 186}
# F1 score: 0.9333342085492967 - Parámetros: {'max_depth': 53, 'n_estimators': 139}
# F1 score: 0.9333329198561884 - Parámetros: {'max_depth': 36, 'n_estimators': 126}
# F1 score: 0.933325008903914 - Parámetros: {'max_depth': 34, 'n_estimators': 148}
# F1 score: 0.9333233739144082 - Parámetros: {'max_depth': 40, 'n_estimators': 148}
# F1 score: 0.9333215560214642 - Parámetros: {'max_depth': 40, 'n_estimators': 241}
# F1 score: 0.9333063019084958 - Parámetros: {'max_depth': 42, 'n_estimators': 172}
# F1 score: 0.9333026585819058 - Parámetros: {'max_depth': 30, 'n_estimators': 62}
# F1 score: 0.9332811639348322 - Parámetros: {'max_depth': 44, 'n_estimators': 86}
# F1 score: 0.9332625998201939 - Parámetros: {'max_depth': 47, 'n_estimators': 255}
# F1 score: 0.9332458927426375 - Parámetros: {'max_depth': 45, 'n_estimators': 121}
# F1 score: 0.9332450518992443 - Parámetros: {'max_depth': 46, 'n_estimators': 155}
# F1 score: 0.9332380818636808 - Parámetros: {'max_depth': 37, 'n_estimators': 111}
# F1 score: 0.933237534385803 - Parámetros: {'max_depth': 42, 'n_estimators': 88}
# F1 score: 0.933210612737257 - Parámetros: {'max_depth': 49, 'n_estimators': 105}
# F1 score: 0.9331892044436338 - Parámetros: {'max_depth': 50, 'n_estimators': 122}
# F1 score: 0.9331709809532531 - Parámetros: {'max_depth': 46, 'n_estimators': 183}
# F1 score: 0.9331648477886303 - Parámetros: {'max_depth': 40, 'n_estimators': 177}
# F1 score: 0.9331647344037796 - Parámetros: {'max_depth': 38, 'n_estimators': 107}
# F1 score: 0.9331309388731418 - Parámetros: {'max_depth': 46, 'n_estimators': 119}
# F1 score: 0.933124698941788 - Parámetros: {'max_depth': 49, 'n_estimators': 115}
# F1 score: 0.9331101481014098 - Parámetros: {'max_depth': 50, 'n_estimators': 86}
# F1 score: 0.9329795944002559 - Parámetros: {'max_depth': 37, 'n_estimators': 98}
# F1 score: 0.9329231246487837 - Parámetros: {'max_depth': 38, 'n_estimators': 55}
# F1 score: 0.9328598803039571 - Parámetros: {'max_depth': 50, 'n_estimators': 52}
# F1 score: 0.9328304948416228 - Parámetros: {'max_depth': 39, 'n_estimators': 55}
# F1 score: 0.9328056132823775 - Parámetros: {'max_depth': 54, 'n_estimators': 63}
# F1 score: 0.9327625281361194 - Parámetros: {'max_depth': 48, 'n_estimators': 69}
# F1 score: 0.932645017353426 - Parámetros: {'max_depth': 50, 'n_estimators': 49}
# F1 score: 0.9323568969999323 - Parámetros: {'max_depth': 52, 'n_estimators': 28}
# F1 score: 0.9323031961856655 - Parámetros: {'max_depth': 19, 'n_estimators': 228}
# F1 score: 0.9322188279301494 - Parámetros: {'max_depth': 49, 'n_estimators': 35}
# F1 score: 0.9321596534000826 - Parámetros: {'max_depth': 47, 'n_estimators': 26}
# F1 score: 0.9320193409298719 - Parámetros: {'max_depth': 19, 'n_estimators': 104}
# F1 score: 0.931322868211344 - Parámetros: {'max_depth': 46, 'n_estimators': 18}
# F1 score: 0.9308746767098756 - Parámetros: {'max_depth': 27, 'n_estimators': 12}
# F1 score: 0.9308618241818806 - Parámetros: {'max_depth': 39, 'n_estimators': 15}
# F1 score: 0.9306252918294101 - Parámetros: {'max_depth': 18, 'n_estimators': 198}
# F1 score: 0.9306135328702696 - Parámetros: {'max_depth': 18, 'n_estimators': 135}
# F1 score: 0.9285066040216975 - Parámetros: {'max_depth': 17, 'n_estimators': 285}
# F1 score: 0.928161445585298 - Parámetros: {'max_depth': 17, 'n_estimators': 239}
# F1 score: 0.9277550390474989 - Parámetros: {'max_depth': 17, 'n_estimators': 68}
# F1 score: 0.9263987329145096 - Parámetros: {'max_depth': 17, 'n_estimators': 25}
# F1 score: 0.9249913350491361 - Parámetros: {'max_depth': 16, 'n_estimators': 164}
# F1 score: 0.9237012997050794 - Parámetros: {'max_depth': 16, 'n_estimators': 33}
# F1 score: 0.9219602162787736 - Parámetros: {'max_depth': 15, 'n_estimators': 139}
# F1 score: 0.9218556464885322 - Parámetros: {'max_depth': 15, 'n_estimators': 191}
# F1 score: 0.9185326764264472 - Parámetros: {'max_depth': 14, 'n_estimators': 207}
# F1 score: 0.9184691508428049 - Parámetros: {'max_depth': 14, 'n_estimators': 203}
# F1 score: 0.9182674169919951 - Parámetros: {'max_depth': 14, 'n_estimators': 80}
# F1 score: 0.9181570113283932 - Parámetros: {'max_depth': 14, 'n_estimators': 50}
# F1 score: 0.9179943724892439 - Parámetros: {'max_depth': 14, 'n_estimators': 57}
# F1 score: 0.9143535183301991 - Parámetros: {'max_depth': 13, 'n_estimators': 236}
# F1 score: 0.9073618725967043 - Parámetros: {'max_depth': 12, 'n_estimators': 112}
# F1 score: 0.9065352353791637 - Parámetros: {'max_depth': 12, 'n_estimators': 107}
# F1 score: 0.9061284408464243 - Parámetros: {'max_depth': 12, 'n_estimators': 282}
# F1 score: 0.8990879417252554 - Parámetros: {'max_depth': 11, 'n_estimators': 132}
# F1 score: 0.8988632613668589 - Parámetros: {'max_depth': 11, 'n_estimators': 168}
# F1 score: 0.8984119963681294 - Parámetros: {'max_depth': 11, 'n_estimators': 67}
# F1 score: 0.8907546608794983 - Parámetros: {'max_depth': 10, 'n_estimators': 179}
# F1 score: 0.8906444131830618 - Parámetros: {'max_depth': 10, 'n_estimators': 128}
# F1 score: 0.8904034978110065 - Parámetros: {'max_depth': 10, 'n_estimators': 161}

# %% [markdown]
# ### Modelo

# %%
rnd_search.best_estimator_.get_params()
# Out:
# {'bootstrap': True,
#  'ccp_alpha': 0.0,
#  'class_weight': None,
#  'criterion': 'gini',
#  'max_depth': 24,
#  'max_features': 'sqrt',
#  'max_leaf_nodes': None,
#  'max_samples': None,
#  'min_impurity_decrease': 0.0,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'monotonic_cst': None,
#  'n_estimators': 246,
#  'n_jobs': -1,
#  'oob_score': False,
#  'random_state': None,
#  'verbose': 0,
#  'warm_start': False}

# %%
# Seleccionamos el mejor modelo
clf_rnd = rnd_search.best_estimator_

# %%
# Predecimos con el conjunto de datos de entrenamiento
y_train_pred = clf_rnd.predict(X_train_reduced)

# %%
# Predicción con el conjunto de datos de entrenamiento
print("F1 score Train Set:", f1_score(y_train_pred, y_train, average='weighted'))
# Out:
# F1 score Train Set: 0.9753489207437736

# %%
# Predecimos con el conjunto de datos de entrenamiento
y_val_pred = clf_rnd.predict(X_val_reduced)

# %%
# Predicción con el conjunto de datos de validación
print("F1 score Validation Set:", f1_score(y_val_pred, y_val, average='weighted'))
# Out:
# F1 score Validation Set: 0.9360347234080588

# %% [markdown]
# ### PCA

# %%
X_df, y_df = remove_labels(df, 'calss')
y_df = y_df.factorize()[0]

# %%
from sklearn.decomposition import PCA

pca = PCA(n_components=0.9999)
df_reduced = pca.fit_transform(X_df)

# %%
print("Número de componentes:", pca.n_components_)
# Out:
# Número de componentes: 11

# %%
pca.explained_variance_ratio_
# Out:
# array([9.16952089e-01, 5.61087653e-02, 2.16566915e-02, 3.65011318e-03,
#        5.56686331e-04, 3.79356201e-04, 1.86256059e-04, 1.75273567e-04,
#        1.38834106e-04, 8.83685900e-05, 4.56458730e-05])

# %%
df_reduced = pd.DataFrame(df_reduced, columns=["c1", "c2", "c3", "c4", "c5", "c6", "c7", "c8", "c9", "c10", "c11"])
df_reduced["Class"] = y_df

# %%
train_set, val_set, test_set = train_val_test_split(df_reduced)

# %%
X_train, y_train = remove_labels(train_set, 'Class')
X_val, y_val = remove_labels(val_set, 'Class')
X_test, y_test = remove_labels(test_set, 'Class')

# %% [markdown]
# ### Random forest

# %%
clf_rnd = RandomForestClassifier(n_estimators=200, max_depth=30, random_state=42, n_jobs=-1)
clf_rnd.fit(X_train, y_train)
# Out:
# RandomForestClassifier(max_depth=30, n_estimators=200, n_jobs=-1,
#                        random_state=42)

# %%
y_val_pred = clf_rnd.predict(X_val)

# %%
print("F1 score validation test:", f1_score(y_val_pred, y_val, average='weighted'))
# Out:
# F1 score validation test: 0.904880286545858

# %%
y_test_pred = clf_rnd.predict(X_test)

# %%
print("F1 score test set:", f1_score(y_test_pred, y_test, average='weighted'))
# Out:
# F1 score test set: 0.9070542131346466
